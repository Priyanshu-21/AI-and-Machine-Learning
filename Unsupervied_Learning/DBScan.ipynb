# %% [markdown]
# ### Introduction to DBScan algorithm
# 1. Density Based Spatial Cluster of Application with Noise (DBSCAN) algorithm
# 2. It is used to define clusters based on density of the datapoint and neighbour datapoints

# %%
#Importing libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#Data collection 
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/r-maSj5Yegvw2sJraT15FA/ODCAF-v1-0.csv"
df = pd.read_csv(url, encoding= 'ISO-8859-1')
df.head(10)
# Out:
#    Index                      Facility_Name  \
# 0      1                   #Hashtag Gallery
# 1      2  'Ksan Historical Village & Museum
# 2      3               'School Days' Museum
# 3      4                   10 Austin Street
# 4      5              10 Gates Dancing Inc.
# 5      6              100 Mile House Branch
# 6      8                       114 Alma St.
# 7      9                  118 Mountain Road
# 8     10        12 Service Battalion Museum
# 9     11                  134 Church Street
#
#                        Source_Facility_Type        ODCAF_Facility_Type  \
# 0                                        ..                    gallery
# 1            historic site-building or park                     museum
# 2                 community/regional museum                     museum
# 3                 built heritage properties  heritage or historic site
# 4                                      arts              miscellaneous
# 5  cariboo regional district library system        library or archives
# 6                 built heritage properties  heritage or historic site
# 7                 built heritage properties  heritage or historic site
# 8                   military museum or fort                     museum
# 9                 built heritage properties  heritage or historic site
#
#                          Provider Unit Street_No     Street_Name Postal_Code  \
# 0                         toronto   ..       801     dundas st w     M6J 1V2
# 1    canadian museums association   ..      1500          62 hwy     V0J 1Y0
# 2    canadian museums association   ..       427        queen st     E3B 5R6
# 3                         moncton   ..        10       austin st     E1C 1Z6
# 4                          ottawa   ..        ..              ..          ..
# 5  government of british columbia   ..       449  birch avenue s     V0K 2E0
# 6                         moncton   ..       114         alma st          ..
# 7                         moncton   ..       118     mountain rd     E1C 2K7
# 8    canadian museums association   ..      5500         no 4 rd     V6X 3L5
# 9                         moncton   ..       134       church st     E1C 4Z6
#
#             City Prov_Terr                              Source_Format_Address  \
# 0        toronto        on                                    801 dundas st w
# 1       hazelton        bc  1500 hwy 62 hazelton british columbia v0j 1y0 ...
# 2    fredericton        nb  427 queen st fredericton new brunswick e3b 5r6...
# 3        moncton        nb                                       10 austin st
# 4         ottawa        on                                                 ..
# 5  pender island        bc                                449 s. birch avenue
# 6        moncton        nb                                        114 alma st
# 7        moncton        nb                                    118 mountain rd
# 8       richmond        bc  5500 no. 4 rd the sherman armoury richmond bri...
# 9        moncton        nb                                      134 church st
#
#                  CSD_Name   CSDUID PRUID     Latitude     Longitude
# 0                 Toronto  3520005    35  43.65169472  -79.40803272
# 1                Hazelton  5949022    59   55.2645508  -127.6428124
# 2             Fredericton  1310032    13    45.963283   -66.6419017
# 3                 Moncton  1307022    13  46.09247776  -64.78022946
# 4                  Ottawa  3506008    35  45.40856224  -75.71536766
# 5  One Hundred Mile House  5941005    59     51.64139    -121.29562
# 6                 Moncton  1307022    13  46.09186844  -64.77860387
# 7                 Moncton  1307022    13  46.09448386  -64.77990581
# 8                Richmond  5915015    59   49.1763542   -123.112783
# 9                 Moncton  1307022    13  46.09253232  -64.77997633

# %%
#Count Each facitiy_name with it's value of occurances 
values = df[df.ODCAF_Facility_Type.values == 'museum']
values.ODCAF_Facility_Type.value_counts()
# Out:
# ODCAF_Facility_Type
# museum    1938
# Name: count, dtype: int64

# %%
#Count Each facitiy_name with it's value of occurances 
values = df['ODCAF_Facility_Type'].values
count = 0
for val in values:
    if (val == 'museum'):
        count += 1

print(count)
# Out:
# 1938

# %% [markdown]
# ### Feature Selection of this problem
# 1. We will be using latitude and longitude of the datapoints to make clusters
# 2. these features will help us to calcuate minPts and epsilon values for DBSCAN approach

# %%
#Feature Selection 
feature_values = df[['Latitude', 'Longitude']]
feature_values.info()

#Count if any not-null value
feature_values.notnull().count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7972 entries, 0 to 7971
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Latitude   7972 non-null   object
#  1   Longitude  7972 non-null   object
# dtypes: object(2)
# memory usage: 124.7+ KB
# Latitude     7972
# Longitude    7972
# dtype: int64

# %%
feature_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7972 entries, 0 to 7971
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Latitude   7972 non-null   object
#  1   Longitude  7972 non-null   object
# dtypes: object(2)
# memory usage: 124.7+ KB

# %%
#convert feature selected values to datatype as float64 values 
df = feature_values
#Remove not floating values 
df = df[df.Latitude != '..']

#Need to strip ',' for the last of each row to make features pure numerical 
df['Latitude'] = df['Latitude'].astype(str).str.rstrip(',').astype(float)

df['Longitude'] = df['Longitude'].astype(str).str.rstrip('.').astype(float)
# Out:
# /tmp/ipykernel_7057/1624244825.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Latitude'] = df['Latitude'].astype(str).str.rstrip(',').astype(float)
# /tmp/ipykernel_7057/1624244825.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Longitude'] = df['Longitude'].astype(str).str.rstrip('.').astype(float)

# %%
#Scaling the coordinates to make it comparable 
#Latitude: - +/- 90, Longitude: - 360 degree 
#So, to make it comparable we need to scale latitude by factor of 2 
scaled_coord = df.copy()
scaled_coord['Latitude'] = 2 * scaled_coord['Latitude']

# %%
#Using DBScan method to build cluster system with coordinates 
from sklearn.cluster import DBSCAN

min_samples = 3
metric = "euclidean"
eps = 0.5

scan = DBSCAN(eps= eps, metric= metric, min_samples= min_samples)

# %%
#Model Fitting
scan.fit(scaled_coord)
# Out:
# DBSCAN(min_samples=3)

# %%
#Model Prediction and cluster making 
df['Cluster'] = scan.fit_predict(scaled_coord)

df['Cluster'].value_counts()
# Out:
# /tmp/ipykernel_7057/2678510566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cluster'] = scan.fit_predict(scaled_coord)
# Cluster
#  0      3853
#  5       601
# -1       329
#  3       317
#  13      185
#         ...
#  117       3
#  119       3
#  120       3
#  121       3
#  122       3
# Name: count, Length: 124, dtype: int64

# %%
#Visualization of DB Scan Model in Canada's Map 
#Setting up the libraries needed
import geopandas as gpd 
import contextily as ctx 
from shapely.geometry import Point

# %%
#Getting the .tiff file to get Canada Map 
import os
import io
import requests
import zipfile

#Get URL of zip file from cloud 
zip_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/YcUk-ytgrPkmvZAh5bf7zA/Canada.zip"

#Home Directory
output_dir = './'
os.makedirs(output_dir, exist_ok= True)

#Step 1: Zipping the file 
response = requests.get(zip_url)
response.raise_for_status()

#Step 2: Open zip file in memory
with zipfile.ZipFile(io.BytesIO(response.content)) as zip_ref:
    #Step 3: Searching for .tiff file in memory
    for file_name in zip_ref.namelist():
        if (file_name.endswith('.tif')):
            zip_ref.extract(file_name, output_dir)
            print(f'Downloaded and extracted file: {file_name}')
# Out:
# Downloaded and extracted file: Canada.tif
