# %% [markdown]
# ### Introduction to Transformers model in Keras
# - Build small neural network to convert English to Spanish translation
# - Attention based NLP system
#
# **Architecture of Transformer model**: -
#
# ![transformer_architecture.png](../Img/transformer_architecture.png)
